# %%
def remove(lst):
    return set(lst)
a = [1, 3, 1, 2, 8,9, 7, 4, 3, 7]
print(remove(a))
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %%
def remove_by_loops(lst):
    new_list = []
    for i in lst:
        if i not in new_list:
            new_list.append(i)
    print(new_list)
remove_by_loops(a)
# Out:
# [1, 3, 2, 8, 9, 7, 4]
