# %%
import random

a = random.sample(range(1,30), 12)
b = random.sample(range(1, 30), 16)
result = [i for i in a if i in b]
print(f"a = {a}")
print(f"b = {b}")
print(result)
# Out:
# a = [15, 7, 21, 23, 25, 16, 28, 27, 26, 5, 4, 13]
# b = [10, 2, 11, 8, 12, 7, 29, 15, 25, 16, 19, 26, 6, 23, 28, 4]
# [15, 7, 23, 25, 16, 28, 26, 4]
